# %% [markdown]
# # Practica Final

# %% [markdown]
# Aldao Amoedo, Héctor
#
# Cabaleiro Pintos, Laura
#
# Cotardo Valcárcel, Donato José
#
# Romero Conde, José

# %% [markdown]
# ---

# %% [markdown]
# ## Preparación de los datos

# %% [markdown]
# El punto 1, está completado, aunque creo que el 1.3, donde preparamos los datos transformandolos y rellanando los nulos está mal.

# %% [markdown]
# ### 1. Cargar los datos y descripción

# %%
using CSV
using DataFrames

# Cargar el archivo CSV en un DataFrame
df = CSV.read("C:\\Users\\TUF-F15\\Desktop\\3ºIA1q\\MAAAI\\Práctica\\Datos_Práctica_Evaluación_1.csv", DataFrame)

num_variables = size(df, 2)
num_instancias = size(df, 1)
num_individuos = length(unique(df[:, 1]))
num_clases_salida = length(unique(df[:, end]))

println("Número de variables: ", num_variables)
println("Número de instancias: ", num_instancias)
println("Número de individuos: ", num_individuos)
println("Número de clases de salida: ", num_clases_salida)
# Out:
# Número de variables: 563
# Número de instancias: 10299
# Número de individuos: 30
# Número de clases de salida: 6

# %% [markdown]
# Los datos dados ya están cargados, y como podemos observar tienen:
# * 563 Variables
# * 10299 Instancias
# * 30 Individuos
# * 6 Clases de salida

# %% [markdown]
# ### 2. Calcular porcentaje de nulos

# %%
# Calcular el porcentaje de nulos por variable
println("Porcentaje de nulos por variable:")
for col in names(df)
    num_nulos = count(ismissing, df[:, col])
    porcentaje_nulos = (num_nulos / size(df, 1)) * 100
    println("$col: $porcentaje_nulos% nulos")
end

# Calcular el porcentaje de nulos en el conjunto total
num_nulos_totales = sum(x -> ismissing(x), eachcol(df) |> Iterators.flatten)
porcentaje_nulos_totales = (num_nulos_totales / (size(df, 1) * size(df, 2))) * 100
println("Porcentaje total de nulos en el conjunto: $porcentaje_nulos_totales%")
# Out:
# Porcentaje de nulos por variable:
# subject: 0.0% nulos
# tBodyAcc-mean()-X: 0.0% nulos
# tBodyAcc-mean()-Y: 0.0% nulos
# tBodyAcc-mean()-Z: 0.0% nulos
# tBodyAcc-std()-X: 0.01941936110301971% nulos
# tBodyAcc-std()-Y: 0.0% nulos
# tBodyAcc-std()-Z: 0.01941936110301971% nulos
# tBodyAcc-mad()-X: 0.01941936110301971% nulos
# tBodyAcc-mad()-Y: 0.029129041654529564% nulos
# tBodyAcc-mad()-Z: 0.029129041654529564% nulos
# tBodyAcc-max()-X: 0.01941936110301971% nulos
# tBodyAcc-max()-Y: 0.0% nulos
# tBodyAcc-max()-Z: 0.009709680551509855% nulos
# tBodyAcc-min()-X: 0.0% nulos
# tBodyAcc-min()-Y: 0.0% nulos
# tBodyAcc-min()-Z: 0.0% nulos
# tBodyAcc-sma(): 0.009709680551509855% nulos
# tBodyAcc-energy()-X: 0.0% nulos
# tBodyAcc-energy()-Y: 0.0% nulos
# tBodyAcc-energy()-Z: 0.0% nulos
# tBodyAcc-iqr()-X: 0.029129041654529564% nulos
# tBodyAcc-iqr()-Y: 0.009709680551509855% nulos
# tBodyAcc-iqr()-Z: 0.0% nulos
# tBodyAcc-entropy()-X: 0.0% nulos
# tBodyAcc-entropy()-Y: 0.0% nulos
# ...

# %% [markdown]
# ### 3. Preparar los datos para las técnicas de clasificación

# %% [markdown]
# Rellenamos valores faltantes

# %%
using Statistics
using StatsBase

# Rellenar valores faltantes
for col in names(df)
    if eltype(df[!, col]) <: Number && eltype(df[!, col]) != Bool  # Columnas numéricas, pero no booleanas
        mean_value = mean(skipmissing(df[!, col]))
        
        # Convertir la columna a Float64 si es necesario
        if eltype(df[!, col]) == Int
            df[!, col] = Float64.(df[!, col])
        end
        
        df[ismissing.(df[!, col]), col] .= mean_value
    elseif eltype(df[!, col]) == Bool  # Columnas booleanas
        mode_value = mode(skipmissing(df[!, col]))  # Rellenar con la moda
        df[ismissing.(df[!, col]), col] .= mode_value
    elseif eltype(df[!, col]) <: AbstractString  # Columnas categóricas
        mode_value = mode(skipmissing(df[!, col]))
        df[ismissing.(df[!, col]), col] .= mode_value
    end
end

println("Valores nulos rellenados.")

# %% [markdown]
# Normalizamos en el rango [0,1]

# %%
# Normalización (0 a 1)
for col in names(df)
    if eltype(df[!, col]) <: Number
        min_val = minimum(df[!, col])
        max_val = maximum(df[!, col])
        df[!, col] = (df[!, col] .- min_val) ./ (max_val - min_val)
    end
end

println("Datos numéricos normalizados.")

# %% [markdown]
# Convertimos variables categóricas a numéricas usando One-Hot Encoding

# %%
using DataFrames

# Iterar sobre las columnas categóricas
for col in names(df)
    if eltype(df[!, col]) <: AbstractString  # Si es una columna categórica
        # Encontrar las categorías únicas
        categorias = unique(df[!, col])
        
        # Crear una nueva columna para cada categoría
        for cat in categorias
            nueva_columna = Symbol("$(col)_$(cat)")
            df[!, nueva_columna] = df[!, col] .== cat
        end
        
        # Opcional: Eliminar la columna categórica original
        select!(df, Not(col))
    end
end

println("One-Hot Encoding aplicado exitosamente.")

# %% [markdown]
# Validamos los datos

# %%
println("Validación de datos:")

# Calcular la cantidad total de valores nulos
total_nulos = sum(col -> count(ismissing, col), eachcol(df))
println("Valores nulos restantes: $total_nulos")

# Verificar tipo de datos de cada columna
println("Tipos de datos por columna:")
for col in names(df)
    println("$col: $(eltype(df[!, col]))")
end

# %% [markdown]
# ### 4. Segmentar el 10% de los datos usando HoldOut

# %%
using CSV
using DataFrames
using Random

Random.seed!(172)

# Identificar la columna de los individuos (por ejemplo, 'subject')
individuos = unique(df[:, :subject])  # Extraer individuos únicos

# Seleccionar aleatoriamente el 10% de los individuos
num_holdout = Int(round(0.1 * length(individuos)))  # 10% de los individuos
holdout_individuos = shuffle(individuos)[1:num_holdout]  # Seleccionar individuos aleatorios

# Dividir el dataset en holdout y resto
holdout_df = filter(row -> row.subject in holdout_individuos, df)
train_df = filter(row -> !(row.subject in holdout_individuos), df)

# Imprimir resultados
println("Individuos en el holdout: ", holdout_individuos)
println("Tamaño del conjunto de entrenamiento: $(size(train_df))")
println("Tamaño del conjunto de holdout: $(size(holdout_df))")

# %%
# Comprobar que no hay intersección entre los conjuntos
holdout_subjects = unique(holdout_df[:, :subject])
train_subjects = unique(train_df[:, :subject])

# Verificar si hay intersección
intersection = intersect(holdout_subjects, train_subjects)

if isempty(intersection)
    println("La división es correcta: no hay individuos compartidos entre los conjuntos.")
else
    println("Error: Hay individuos compartidos entre los conjuntos.")
    println("Individuos compartidos: $intersection")
end

# %% [markdown]
# ### 5. 5 fold cross-validation

# %%
Random.seed!(172)

# Identificar individuos únicos
individuos = unique(df[:, :subject])

# Dividir los individuos en 5 grupos (folds)
n_folds = 5
fold_indices = randperm(length(individuos))  # Permutar aleatoriamente los índices
fold_size = Int(round(length(individuos) / n_folds))
folds = [individuos[fold_indices[(i - 1) * fold_size + 1:min(i * fold_size, end)]] for i in 1:n_folds]

# Crear folds a nivel de instancias
fold_data = []
for fold in folds
    push!(fold_data, filter(row -> row.subject in fold, df))
end

# Imprimir resumen de los folds
for (i, fold) in enumerate(fold_data)
    println("Fold $i:")
    println("Número de participantes: $(length(unique(fold[:, :subject])))")
    println("Número de instancias: $(size(fold, 1))")
    println("Participantes: $(unique(fold[:, :subject]))")
end

# %% [markdown]
# ### 6. Normalizar usando MinMaxScaler

# %%
# Función para aplicar MinMaxScaler a un DataFrame
function normalize_minmax(df::DataFrame)
    for col in names(df)
        if eltype(df[!, col]) <: Number  # Solo aplicamos a columnas numéricas
            col_min = minimum(df[!, col])
            col_max = maximum(df[!, col])
            if col_min != col_max  # Evitar división por cero
                df[!, col] = (df[!, col] .- col_min) ./ (col_max - col_min)
            else
                df[!, col] .= 0.0  # Si todos los valores son iguales, asignamos 0
            end
        end
    end
    return df
end

# Aplicar normalización a cada fold
normalized_folds = []
for (i, fold) in enumerate(fold_data)
    println("Normalizando Fold $i...")
    push!(normalized_folds, normalize_minmax(deepcopy(fold)))  # Usar deepcopy para no modificar los datos originales
end

# Resumen de los folds normalizados
for (i, fold) in enumerate(normalized_folds)
    println("Fold $i normalizado:")
    println(fold)
end

# %% [markdown]
# ---

# %% [markdown]
# ## Creación de los modelos básicos

# %% [markdown]
# ### Reducciones de dimensionalidad

# %% [markdown]
# ### Otras técnicas

# %% [markdown]
# ### Clasificadores

# %% [markdown]
# ---

# %% [markdown]
# ## Creación de los modelos ensemble

# %% [markdown]
# ---

# %% [markdown]
# ## Conclusiones
